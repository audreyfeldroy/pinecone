# %% [markdown]
# # Ellipse

# %%
from pinecone import *

im = size(600, 400)
ellipse(300, 200, 100, 40)

import numpy as np
from matplotlib.pyplot import imshow
# %matplotlib inline
imshow(np.asarray(im))

# %%
def show_in_notebook(img):
    import numpy as np
    from matplotlib.pyplot import imshow
    get_ipython().magic('matplotlib inline')
    imshow(np.asarray(img))

# %%
from pinecone import size, ellipse

im = size(600, 400)
ellipse(300, 200, 100, 40)

show_in_notebook(im)
# Out:
# /var/folders/8n/8bp9lk9n1sj1cfb11k87mgdc0000gn/T/ipykernel_20767/166473296.py:4: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic('matplotlib inline')
